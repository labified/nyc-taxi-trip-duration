# %%
import pandas as pd
import numpy as np
import pytz as tz

# %%
train = pd.read_csv('./train.csv')

# %%
train['pickup_datetime'] = pd.to_datetime(train['pickup_datetime'],infer_datetime_format=True)
train['dropoff_datetime'] = pd.to_datetime(train['dropoff_datetime'],infer_datetime_format=True)
print(train['pickup_datetime'].min())
print(train['pickup_datetime'].max())
print(train['dropoff_datetime'].min())
print(train['dropoff_datetime'].max())
# Out:
# 2016-01-01 00:00:17
# 2016-06-30 23:59:39
# 2016-01-01 00:03:31
# 2016-07-01 23:02:03

# %%
def to_epoch(ts):
    if ts < pd.Timestamp('2016-03-13 02:00'):
        return int((ts - pd.Timestamp('1970-01-01')) / np.timedelta64(1, 's'))
    else:
        return int((ts - pd.Timestamp('1970-01-01 01:00:00')) / np.timedelta64(1, 's'))

# %%
train['pickup_datetime_epoch'] = train['pickup_datetime'].apply(to_epoch)
train['dropoff_datetime_epoch'] = train['dropoff_datetime'].apply(to_epoch)

# %%
train.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  pickup_datetime_epoch  \
# ...

# %%
train.to_csv('train_epoch.csv')

# %%
sample = pd.read_csv('./train.csv', nrows=100)
sample
# Out:
#            id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0   id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1   id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2   id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3   id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4   id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# 5   id0801584          2  2016-01-30 22:01:40  2016-01-30 22:09:03
# 6   id1813257          1  2016-06-17 22:34:59  2016-06-17 22:40:40
# 7   id1324603          2  2016-05-21 07:54:58  2016-05-21 08:20:49
# 8   id1301050          1  2016-05-27 23:12:23  2016-05-27 23:16:38
# 9   id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 10  id1436371          2  2016-05-10 22:08:41  2016-05-10 22:29:55
# 11  id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# 12  id1187965          2  2016-02-19 09:52:46  2016-02-19 10:11:20
# ...

# %%
sample['pickup_datetime'] = pd.to_datetime(sample['pickup_datetime'],infer_datetime_format=True)
sample['dropoff_datetime'] = pd.to_datetime(sample['dropoff_datetime'],infer_datetime_format=True)
sample.info()

# %%
int(round(sample['pickup_longitude'].astype(float) * 10000))
#sample['pickup_long_10m'] = int(round(sample['pickup_longitude'] * 10000))
#sample['pickup_lat_10m'] = int(round(sample['pickup_latitude'] * 10000))
